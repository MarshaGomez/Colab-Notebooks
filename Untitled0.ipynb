# %%
searchfile = open(COCO_CAPTIONS_DATASET)

for line in searchfile:
  print("search"+search)
  if search in line: 
    print("search"+search.zfill(12))

    

filenames = os.listdir(IMG_DIR)
for filename in filenames:
  if filename.endswith('.jpg'):
    print("filename" + filename[0:12])
    print(str(int(filename[0:12])))
    #print(filename[0:12].zfill(12))


searchfile.close()
