# %%
def reverserWords(inString):
    inString = inString.split()
    final = []
    for inStr in inString: 
      print(inStr)
      inStr.sort()
      for vecStr in inStr:
        print(vecStr)

            #vecStr.sort()
    return 1


    str1 = ""  

    for ele in s:  
        str1 += ele   
    
    return str1  


reverserWords("Hello world")
# Out:
# Hello
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e5a8b1d5ce12> in <module>()
#      11
#      12
# ---> 13 reverserWords("Hello world")
#
# <ipython-input-14-e5a8b1d5ce12> in reverserWords(inString)
#       3     for inStr in inString:
#       4       print(inStr)
# ----> 5       inStr.sort()
#       6       for vecStr in inStr:
#       7         print(vecStr)
#
# AttributeError: 'str' object has no attribute 'sort'
